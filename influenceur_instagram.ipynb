# %%
import instaloader
import pandas as pd
from itertools import islice
from math import ceil
from datetime import datetime
from itertools import dropwhile, takewhile
from instaloader import Instaloader, Profile
import re

# %%
import matplotlib.pyplot as plt

# %%
loader = instaloader.Instaloader()
#loader.login('orthlane_w',passwd="i miss you") : Sahar
#loader.login('orthalne_s',passwd="1234orth") : Sana
#loader.login('Wiwiyet',passwd="Wiwiyet1234") : Mail enis
loader.login('Wiwiyet',passwd="Wiwiyet1234")

# %%
def influenceur_instagram(key) :
    mot=key
    #Ajouter le mot choisi dans une liste
    mots=[]
    mots.append(mot)
    
    #Extraction des profiles liés au mots clés 
    profil_mots={}
    for i in (mots):
        s=instaloader.TopSearchResults(loader.context,i).get_profiles()
        l=[profile.username for profile in s]
        profil_mots[i]=l

    #Extraction des informations liés au profile
    for valeur in profil_mots.values()  :
        liste_1=[]
        for k in valeur :
            try:
                profile = instaloader.Profile.from_username(loader.context,k)
                _followers=(profile.followers)
                _username=profile.username
                _userid=(profile.userid)
                _profile_pic=(profile.profile_pic_url)
                _mediacount=(profile.mediacount)
                _followees=(profile.followees)
                _biography=(profile.biography)
                _external_url=(profile.external_url)
                _private=(profile.is_private)
                _business_account=(profile.is_business_account)
                _business_category_name=(profile.business_category_name)
                #finding all valid emails using regex
                email = re.findall(r"[A-Za-z0-9_%+-.]+"
                                r"@[A-Za-z0-9.-]+"
                                r"\.[A-Za-z]{2,5}",_biography,flags=re.IGNORECASE)
                
                phone_pattern = re.compile(r'((?:\+\d{2}[-.\s]?(?:\(0\)|0)*?[-.\s]?|00[-.\s]?\d{2}[-.\s]?(?:\(0\)|0)*?[-.\s]?|0)\d?[-.\s]?(?:\d{2}[-.\s]?){3,4})(?:$|\D)')
                phone = re.findall(phone_pattern,_biography)

                #localisation 
                Localisations = ['parisian','France', 'france', 'française', 'Française', 'French','Île-de-France','Cannes','cannes' ,'Paris', 'paris', 'Lyon', 'lyon','Brussels','Nantes', 'bruxelles', 'Marseille', 'marseille', 'Nice', 'nice', 'Toulouse', 'toulouse', 'Bordeaux', 'bordeaux', 'Caen', 'caen', 'Lille', 'lille']
                liste_de_chaine = [] #split la chaine en mots
                loc_cherchée = " " #final
                _localisation = []
                liste_de_chaine = _biography.split()
                for e in liste_de_chaine:
                    for k in Localisations:
                        if (e == k):
                            loc_cherchée = e
                            _localisation.append(loc_cherchée)
                if (loc_cherchée == " "):
                    _localisation.append(" ")
                loc_cherchée = " "
                
                if (_followers>=3000):
                    Liste=[]
                    Liste.append(_username)
                    Liste.append(_userid)
                    Liste.append(_profile_pic)
                    Liste.append(_mediacount)
                    Liste.append(_followers) 
                    Liste.append(_followees)
                    Liste.append(_biography)
                    Liste.append(_localisation)
                    Liste.append(email)
                    Liste.append(phone)
                    Liste.append(_external_url)
                    Liste.append(_private)
                    Liste.append(_business_account)
                    Liste.append(_business_category_name)
                    liste_1.append(Liste)
                else:
                    pass
                #Création d'un fichier csv pour stocker les données
                path=['C:/Users/User/Desktop/orthlane/data_final/']
                ext=['.csv']
                a=path[0]+mots[0]+ext[0]
                df=pd.DataFrame(liste_1,columns = ['Username','User ID','Picture','Number of posts','Followers','Followees','bio','Location','email','Phone','url externe','isPrivate','isBusiness','BusinessType'])
                df.to_csv(a, index=False)
            except :
                pass

# %%
influenceur_instagram('femme')
# Out:
# JSON Query to api/v1/users/web_profile_info/?username=femmes_des_joueurs: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    1    1    2    2    2    4
#  *                           iphone:    1    1   99   99   99  290
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 11 minutes, at 11:37.
# JSON Query to api/v1/users/web_profile_info/?username=femmes_des_joueurs: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    4
#  *                           iphone:    1    1    2    2   91  286
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 20 seconds, at 11:37.
# JSON Query to api/v1/users/web_profile_info/?username=femmeebeneyt: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:    3    3    4    4   89  288
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 36 seconds, at 11:38.
# JSON Query to api/v1/users/web_profile_info/?username=femmeebeneyt: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:    4    4    5    5   78  276
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 11:38.
# JSON Query to api/v1/users/web_profile_info/?username=mz.femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:    6    6    7    7   73  269
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 30 seconds, at 11:39.
# JSON Query to api/v1/users/web_profile_info/?username=mz.femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:    7    7    8    8   62  253
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 20 seconds, at 11:39.
# JSON Query to api/v1/users/web_profile_info/?username=femmes_de_tunisie_officiel: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:    9    9   10   10   56  245
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 18 seconds, at 11:40.
# JSON Query to api/v1/users/web_profile_info/?username=femmes_de_tunisie_officiel: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:   10   10   11   11   48  238
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 21 seconds, at 11:40.
# JSON Query to api/v1/users/web_profile_info/?username=sac.pour.femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:   12   12   13   13   38  231
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 18 seconds, at 11:40.
# JSON Query to api/v1/users/web_profile_info/?username=sac.pour.femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:   13   13   14   14   30  225
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 11:41.
# JSON Query to api/v1/users/web_profile_info/?username=femme_elegante13: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:   15   15   16   16   22  212
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 11:41.
# JSON Query to api/v1/users/web_profile_info/?username=femme_elegante13: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    1    1    1    3
#  *                           iphone:   16   16   17   17   17  206
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 15 minutes, at 11:56.
# JSON Query to api/v1/users/web_profile_info/?username=femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    2
#  *                           iphone:    2    2   18   18   18  117
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 11 minutes, at 12:07.
# JSON Query to api/v1/users/web_profile_info/?username=femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    1    1    3    3   18  105
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 20 seconds, at 12:08.
# JSON Query to api/v1/users/web_profile_info/?username=_femme_positive_: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    3    3    5    5   18  107
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 39 seconds, at 12:08.
# JSON Query to api/v1/users/web_profile_info/?username=_femme_positive_: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    4    4    6    6   17   89
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 12:09.
# JSON Query to api/v1/users/web_profile_info/?username=femme_de_style_: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    6    6    8    8   18   83
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 23 seconds, at 12:09.
# JSON Query to api/v1/users/web_profile_info/?username=femme_de_style_: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    7    7    9    9   18   74
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 12:10.
# JSON Query to api/v1/users/web_profile_info/?username=parfumerie_belle_femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:    9    9   11   11   18   65
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 12:10.
# JSON Query to api/v1/users/web_profile_info/?username=parfumerie_belle_femme: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:   10   10   12   12   18   56
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 20 seconds, at 12:10.
# JSON Query to api/v1/users/web_profile_info/?username=dngongue_femme_fatale: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:   12   12   14   14   18   47
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 19 seconds, at 12:11.
# JSON Query to api/v1/users/web_profile_info/?username=dngongue_femme_fatale: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:   13   13   15   15   18   41
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 21 seconds, at 12:11.
# JSON Query to api/v1/users/web_profile_info/?username=la__femme_algerienne: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:   15   15   17   17   18   34
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 21 seconds, at 12:11.
# JSON Query to api/v1/users/web_profile_info/?username=la__femme_algerienne: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    1
#  *                           iphone:   16   16   18   18   18   35
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 15 minutes, at 12:26.
# JSON Query to api/v1/users/web_profile_info/?username=femmedinfluencemag: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:    0    0    0    0    0    0
#  *                           iphone:    2    2   18   18   18   36
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 11 minutes, at 12:38.
