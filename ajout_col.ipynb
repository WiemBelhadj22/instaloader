# %%
import csv
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\User\Desktop\orthlane\data_final\bisous.csv')

# %%
df.columns
# Out:
# Index(['Username', 'User ID', 'Picture', 'Number of posts', 'Followers',
#        'Followees', 'bio', 'Location', 'email', 'Phone', 'url externe',
#        'isPrivate', 'isBusiness', 'BusinessType'],
#       dtype='object')

# %%
#Effacer les redendances
df.drop_duplicates(subset="Username",inplace=True)

# %%
#Ajouter une colone de langue et appender les résultats
df['langue']=''
from langdetect import detect
def langue(x):
    try:
        lang = detect(x)
    except:
        lang = 'Other'
    return lang
for i in df.index:
    a=langue(df['bio'][i])
    df['langue'][i]=a
    print(df['langue'][i])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21692\1788885687.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['langue'][i]=a
# id
# en
# en
# ca
# fr
# en
# en
# en
# en
# ja
# en
# fr
# en
# en
# Other
# en
# en

# %%
df['Engagement Rate']=0.

# %%
#Visualiser les Followers/Followees
fig,ax=plt.subplots()
df_2=pd.DataFrame({'Followers':list(df['Followers']),'Followees':list(df['Followees'])},index=list(df['Username']))
df_2.plot.bar(figsize =(30,30),ax=ax)
# Out:
# <AxesSubplot:>

# %%
#Visualiser les Followers/Followees/Number of posts
fig,ax=plt.subplots()
df_3=pd.DataFrame({'Number of posts':list(df['Number of posts']),'Followers':list(df['Followers']),'Followees':list(df['Followees'])},index=list(df['Username']))
df_3.plot.bar(figsize =(30,30),ax=ax)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                   Username      User ID  \
# 0     fatima_225__officiel  53660261457
# 1   fatima__225__officiel_  47047846707
# 2         bisousbisousclub  14207971212
# 3               bisous.fee     40946903
# 4           bisous.violets    965155353
# 5              bisous_peru  15369224470
# 6            bisous_events   1545009309
# 7       bisousbathluxuries  18298346866
# 8               bisousatoi    241302246
# 9              cafe_bisous  11872235502
# 10        bisous_andthebay  44826496483
# 11            bisous_dours   1929698203
# 12          vintage.bisous  45682061384
# 13  bisousbisouspatisserie    361353485
# 14   bisousbisous_official     14770641
# 15             grosbisouus   3510262456
# 16             iwearbisous   1401058565
#
#                                               Picture  Number of posts  \
# 0   https://instagram.ftun10-1.fna.fbcdn.net/v/t51...               23
# 1   https://instagram.ftun10-1.fna.fbcdn.net/v/t51...              143
# ...
